# %%
import pandas as pd

# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
from flask_pymongo import PyMongo
from flask import Flask

# %%
from re import search

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST driver version for 97.0.4692
# There is no [mac64] chromedriver for browser 97.0.4692 in cache
# Get LATEST driver version for 97.0.4692
# Trying to download new driver from https://chromedriver.storage.googleapis.com/97.0.4692.71/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/jameswhite/.wdm/drivers/chromedriver/mac64/97.0.4692.71]

# %%
url = 'https://elanthipedia.play.net/Category:Weapons'
browser.visit(url)

# %%
title_list = []

# %%
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
# Retrieve all elements that contain book information
articles = soup.find('div', class_='mw-category-group')
# list_list = articles.find('li')

# %%
# Iterate through all pages
for x in range(200):
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.find_all('li')

    for article in articles:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        link = article.find('a')
#         print(link)
#         href = link['href']
        try:
            title = link['title']
            if search('Weapon', title):
                title_list.append(title)
            else:
                pass
        except:
            pass

    # Click the 'Next' button on each page
    try:
        browser.links.find_by_partial_text('next page').click()
          
    except:
        print("Scraping Complete")
# Out:
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# ...

# %%
# headlines_list = []

# for category in headlines:
#     title = category.text.strip()
#     headlines_list.append(title)
    
# headlines_list

# %%
title_list
# Out:
# ['Weapon:"ATTENTION STARVED" arrow',
#  'Weapon:"BOOT LICKER" bolt',
#  'Weapon:"BROWN-NOSER" bolt',
#  'Weapon:"CAPITULATE" arrow',
#  'Weapon:"CAUTION: POINTY" spear',
#  'Weapon:"CLOTPOLE" bolt',
#  'Weapon:"COME AT ME" arrow',
#  'Weapon:"DIE!" pellet',
#  'Weapon:"DONE YET?" spear',
#  'Weapon:"DOOFUS" pellet',
#  'Weapon:"FLAP-DRAGON" bolt',
#  'Weapon:"FLAX-WENCH" arrow',
#  'Weapon:"FROG-WART" bolt',
#  'Weapon:"GET WELL SOON" spear',
#  'Weapon:"GOBLIN-FACE" bolt',
#  'Weapon:"GOBSNOT" spear',
#  'Weapon:"GOOBER" arrow',
#  'Weapon:"GOT ISSUES" arrow',
#  'Weapon:"GOT ISSUES" bolt',
#  'Weapon:"GROUND-SWILL" arrow',
#  'Weapon:"HA-HA" spear',
#  'Weapon:"HANDS OFF" spear',
#  'Weapon:"HARPY" pellet',
#  'Weapon:"HEDGE-PIG" arrow',
#  'Weapon:"I DARE YOU" arrow',
#  'Weapon:"JACK-A-NAPE" bolt',
#  'Weapon:"JOLTHEAD" bolt',
#  'Weapon:"KISS OFF" bolt',
#  'Weapon:"LAZY" arrow',
#  'Weapon:"LEECH BREATH" bolt',
#  'Weapon:"LEWDSTER" arrow',
#  'Weapon:"LINE SKIPPER" arrow',
# ...

# %%
len(title_list)
# Out:
# 18353

# %%
df = pd.DataFrame(title_list)

# %%
df.to_csv('weapons.csv')

# %%
url_2 = ('https://elanthipedia.play.net/Category:Armor')
browser.visit(url_2)

# %%
armor_list = []

# %%
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
# Retrieve all elements that contain book information
articles = soup.find('div', class_='mw-category-group')
# list_list = articles.find('li')

# %%
# Iterate through all pages
for x in range(200):
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.find_all('li')

    for article in articles:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        link = article.find('a')
#         print(link)
#         href = link['href']
        try:
            title = link['title']
            if search('Armor', title):
                armor_list.append(title)
            else:
                pass
        except:
            pass

    # Click the 'Next' button on each page
    try:
        browser.links.find_by_partial_text('next page').click()
          
    except:
        print("Scraping Complete")
# Out:
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# ...

# %%
len(armor_list)
# Out:
# 20383

# %%
new_df = pd.DataFrame(armor_list)

# %%
new_df.to_csv('armor.csv')

# %%
url_2 = ('https://elanthipedia.play.net/Category:Shields')
browser.visit(url_2)
shield_list = []
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
# Retrieve all elements that contain book information
articles = soup.find('div', class_='mw-category-group')
# Iterate through all pages
for x in range(200):
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.find_all('li')

    for article in articles:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        link = article.find('a')
#         print(link)
#         href = link['href']
        try:
            title = link['title']
            if search('Shield', title):
                shield_list.append(title)
            else:
                pass
        except:
            pass

    # Click the 'Next' button on each page
    try:
        browser.links.find_by_partial_text('next page').click()
          
    except:
        print("Scraping Complete")
# Out:
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# ...

# %%
third_df = pd.DataFrame(shield_list)

# %%
third_df.to_csv('shields.csv')

# %%
url_2 = ('https://elanthipedia.play.net/Category:Weapons')
browser.visit(url_2)
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
# Retrieve all elements that contain book information
articles = soup.find('div', class_='mw-category-group')
# Iterate through all pages
for x in title_list:
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    articles = soup.find_all('li')

    for article in articles:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        link = article.find('a')
#         print(link)
#         href = link['href']
        try:
            title = link['title']
            if search(title_list[x], title):
                link.click()
            else:
                pass
        except:
            pass

    # Click the 'Next' button on each page
    try:
        browser.links.find_by_partial_text('next page').click()
          
    except:
        print("Scraping Complete")
# Out:
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# Scraping Complete
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/opt/anaconda3/envs/TensorFlow/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/envs/TensorFlow/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/opt/anaconda3/envs/TensorFlow/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
# Out:
# 'Weapon:"CAPITULATE" arrow'
